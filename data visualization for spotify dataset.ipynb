# %%
import pandas as pd
import seaborn
import matplotlib.pyplot as plt
spotify_data = pd.read_csv("spotify-2023.csv", encoding='ISO-8859-1')
# 1. What are the top 5 songs and artists released in 2023?
topFiveSongs = spotify_data['track_name'].head(5)
topFiveArtists = spotify_data['artist(s)_name'].head(5)
# for i in topFiveArtists:
#     numOfArtists = len(i)
#     print(numOfArtists)
songs = pd.DataFrame(spotify_data) 
# x = 
print(topFiveSongs)
print(topFiveArtists)


seaborn.barplot(x=len(topFiveSongs), y=topFiveSongs,data= songs )

plt.show() # shows number of artists in each song

# 2. What are the 5 least popular songs and artists released in 2023?
LeastFiveSongs = spotify_data['track_name'].tail(5)
LeastFiveArtists = spotify_data['artist(s)_name'].tail(5)
print(LeastFiveSongs)
print(LeastFiveArtists)

# 3. What are the top 10 most popular songs of 2023?
mostPopular = spotify_data['released_year' == 2023].head(10)
print(mostPopular)
# Out:
# 0    Seven (feat. Latto) (Explicit Ver.)
# 1                                   LALA
# 2                                vampire
# 3                           Cruel Summer
# 4                         WHERE SHE GOES
# Name: track_name, dtype: object
# 0    Latto, Jung Kook
# 1         Myke Towers
# 2      Olivia Rodrigo
# 3        Taylor Swift
# 4           Bad Bunny
# Name: artist(s)_name, dtype: object
# 948                 My Mind & Me
# 949    Bigger Than The Whole Sky
# 950         A Veces (feat. Feid)
# 951                En La De Ella
# 952                        Alone
# Name: track_name, dtype: object
# 948          Selena Gomez
# 949          Taylor Swift
# 950    Feid, Paulo Londra
# 951    Feid, Sech, Jhayco
# 952             Burna Boy
# Name: artist(s)_name, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 28
#      25 print(LeastFiveArtists)
#      27 # 3. What are the top 10 most popular songs of 2023?
# ---> 28 mostPopular = spotify_data['released_year' == 2023].head(10)
#      29 print(mostPopular)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: False
